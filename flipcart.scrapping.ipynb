# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
r = requests.get("https://www.flipkart.com/search?q=lapt&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
r
# Out:
# <Response [200]>

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />
# 	<link href="https://img1a.flixcart.com" rel="dns-prefetch" />
# 	<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e527e7.css" />
#
# 	<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">
#
# 	<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>
# 	<meta http-equiv="X-UA-Compatible" content="I

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(r.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.e527e7.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
main_box = soup.find_all('div',{"class":"_1UoZlX"})

# %%
len(main_box)
# Out:
# 24

# %%
box = main_box[0]

# %%
title=box.find("div",{"class":"_3wU53n"}).text.strip()

# %%
price=box.find("div",{"class":"_1vC4OE _2rQ-NK"}).text.replace('₹','').strip()

# %%
price
# Out:
# '49,990'

# %%
type(box.find("div",{"class":"_1vC4OE _2rQ-NK"}))
# Out:
# bs4.element.Tag

# %%
rating = box.find("div",{"class":"hGSR34"}).text.strip()

# %%
print(title,price,rating)
# Out:
# Acer Nitro 5 Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX 1650)... 49,990 4.4

# %%
data_list = []
for box in main_box:
    temp_dict = {}
    temp_dict['TITLE']=box.find("div",{"class":"_3wU53n"}).text.strip()
    temp_dict['PRICE']=box.find("div",{"class":"_1vC4OE _2rQ-NK"}).text.replace('₹','').strip()
    temp_dict['RATING']=box.find("div",{"class":"hGSR34"}).text.strip()
    data_list.append(temp_dict)

# %%
data_list
# Out:
# [{'TITLE': 'Acer Nitro 5 Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX 1650)...',
#   'PRICE': '49,990',
#   'RATING': '4.4'},
#  {'TITLE': 'Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 TB HDD/Windows 10 Home) 130-15IKB Laptop',
#   'PRICE': '27,990',
#   'RATING': '4'},
#  {'TITLE': 'HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Windows 10 Home) 14q-cy0006AU Thin and Light Laptop',
#   'PRICE': '19,990',
#   'RATING': '4.1'},
#  {'TITLE': 'HP 14q Core i3 7th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14q-cs0023TU Thin and Light Laptop',
#   'PRICE': '32,990',
#   'RATING': '4.3'},
#  {'TITLE': 'HP Pavilion x360 Core i3 8th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14-dh0107TU 2 in 1 Laptop',
#   'PRICE': '41,990',
#   'RATING': '4.5'},
#  {'TITLE': 'HP 15s Ryzen 3 Dual Core - (4 GB/256 GB SSD/Windows 10 Home) 15s-eq0007AU Thin and Light Laptop',
#   'PRICE': '28,990',
#   'RATING': '4.2'},
# ...

# %%
import pandas as pd
df = pd.DataFrame(data_list)

# %%
df
# Out:
#                                                 TITLE   PRICE RATING
# 0   Acer Nitro 5 Ryzen 5 Quad Core - (8 GB/1 TB HD...  49,990    4.4
# 1   Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  27,990      4
# 2   HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19,990    4.1
# 3   HP 14q Core i3 7th Gen - (8 GB/256 GB SSD/Wind...  32,990    4.3
# 4   HP Pavilion x360 Core i3 8th Gen - (4 GB/256 G...  41,990    4.5
# 5   HP 15s Ryzen 3 Dual Core - (4 GB/256 GB SSD/Wi...  28,990    4.2
# 6   HP 14q Core i5 8th Gen - (8 GB/1 TB HDD/Window...  41,990    4.2
# 7   Dell 14 3000 Core i3 7th Gen - (4 GB/1 TB HDD/...  25,490    4.1
# 8   Lenovo Ideapad L340 Core i5 8th Gen - (8 GB/1 ...  64,090    4.1
# 9   Asus VivoBook Gaming Core i7 9th Gen - (16 GB ...  75,990    4.2
# 10  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26,990      4
# 11  Acer Nitro 5 Core i7 9th Gen - (8 GB/1 TB HDD/...  69,990    4.6
# 12  HP 15q Core i3 7th Gen - (8 GB/1 TB HDD/DOS) 1...  30,990    4.3
# ...
